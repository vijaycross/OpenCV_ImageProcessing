# %%
from PIL import Image

# %%
im_file = "page_01.jpg"

# %%
im = Image.open(im_file)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1522>

# %%
print(im.size)
# Out:
# (1200, 1522)

# %%
im.show()

# %%
im.rotate(90).show()

# %%
# im.save("page_0123456.jpg")
